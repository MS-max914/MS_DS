# %%
Домашнее задание "Математический анализ. Производная".
Уровень 0:
Посчитайте значение первой и второй производной функции:
    
𝑓(𝑥)=𝑥5+4𝑠𝑖𝑛(2𝑥)+𝑐𝑜𝑠(3𝑥+3) 

В точке x = 1.

Уровень 1:
Постройте график первой и второй производной функции:
𝑓(𝑥)=𝑠𝑖𝑛5(2𝑥+1) 
На отрезке [-5; 5].

# %%
import numpy as np
import math
from scipy.misc import derivative
import matplotlib.pyplot as plt

# %% [markdown]
# Посчитайте значение первой и второй производной функции:

# %%
def f(x):
    return x**5 + 4*math.sin(math.radians(2*x)) + math.cos(math.radians(3*x+3))

# %%
derivative(f, 1.0 , dx=1e-6, n=1 ) #первая производная в точке 1
# Out:
# 5.1340681856970605

# %%
derivative(f, 1.0 , dx=1e-6, n=2 ) #вторая производная в точке 1
# Out:
# 19.99644894112862

# %% [markdown]
# Уровень 1:
# Постройте график первой и второй производной функции:
# 𝑓(𝑥)=𝑠𝑖𝑛5(2𝑥+1)
# На отрезке [-5; 5].

# %%
def f1(x):
    return math.sin(math.radians(2*x+1))**5

# %%
x = np.linspace(-5, 5)

# %%
der1 = [derivative(f1, xx, dx=1e-6, n=1) for xx in x]
der2 = [derivative(f1, xx, dx=1e-6, n=2) for xx in x]

# %%
plt.plot(x, der1, label="derivative1")
plt.legend()
plt.show()

# %%
plt.plot(x, der2, label="derivative2")
plt.legend()
plt.show()
